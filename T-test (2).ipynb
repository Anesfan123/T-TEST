# %%
#Dataset och kod från Kaggle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re

import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
df = pd.read_csv('museums.csv', low_memory=False)
df.head()
# Out:
#     Museum ID                                        Museum Name  \
# 0  8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1  8400200117                            ALASKA BOTANICAL GARDEN
# 2  8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3  8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4  8400200027                             ALASKA HERITAGE MUSEUM
#
#                                           Legal Name Alternate Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM            NaN
# 1                        ALASKA BOTANICAL GARDEN INC            NaN
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...            NaN
# 3                ALASKA EDUCATORS HISTORICAL SOCIETY            NaN
# 4                    ALASKA AVIATION HERITAGE MUSEUM            NaN
#
#                                      Museum Type Institution Name  \
# 0                                 HISTORY MUSEUM              NaN
# ...

# %%
#heart = pd.read_csv("Heart Attack Data Set.csv")
#happines = pd.read_csv("museums.csv")
#expected_value = 0
#happines.describe()

df.dtypes
# Out:
# Museum ID                                     int64
# Museum Name                                  object
# Legal Name                                   object
# Alternate Name                               object
# Museum Type                                  object
# Institution Name                             object
# Street Address (Administrative Location)     object
# City (Administrative Location)               object
# State (Administrative Location)              object
# Zip Code (Administrative Location)           object
# Street Address (Physical Location)           object
# City (Physical Location)                     object
# State (Physical Location)                    object
# Zip Code (Physical Location)                float64
# Phone Number                                 object
# Latitude                                    float64
# Longitude                                   float64
# Locale Code (NCES)                          float64
# ...

# %%
#t_statistic, p_value = stats.ttest_1samp(happines['Healthy life expectancy'], expected_value)

df['Museum Type'].value_counts()
df['Type'] = df['Museum Type'].apply(lambda x: 'ZOO' if re.search('ZOO', x) else 'OTHERS')
df['Type'].value_counts()
# Out:
# OTHERS    32508
# ZOO         564
# Name: Type, dtype: int64

# %%
zoo = df[df['Type'] == 'ZOO']['Revenue']
others = df[df['Type'] == 'OTHERS']['Revenue']

zoo = zoo[zoo > 0]
others = others[others > 0]

zoo = (zoo+1).apply(np.log)
others = (others+1).apply(np.log)

# %%
#print("T-statistic:", t_statistic)
#print("P-värde:", p_value)
stats.ttest_ind(a= zoo,
                b= others,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=8.17114572133828, pvalue=2.190826261598194e-14)
